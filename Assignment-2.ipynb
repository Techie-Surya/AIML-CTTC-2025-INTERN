# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Auto Mpg Set

# %%
auto = pd.read_csv(r"C:\Users\surya\OneDrive\Desktop\AIML_CTTC\NOTES\auto-mpg.csv")
auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
auto.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
for i in auto.columns:
    print(f"{i}: \n {auto[i].unique()} \n")
# Out:
# mpg:
#  [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]
#
# cylinders:
#  [8 4 6 3 5]
#
# displacement:
#  [307.  350.  318.  304.  302.  429.  454.  440.  455.  390.  383.  340.
#  400.  113.  198.  199.  200.   97.  110.  107.  104.  121.  360.  140.
#   98.  232.  225.  250.  351.  258.  122.  116.   79.   88.   71.   72.
# ...

# %%
for i in auto.columns:
    print(f"{i}: {sum(auto[i]=='?')}")
# Out:
# mpg: 0
# cylinders: 0
# displacement: 0
# horsepower: 6
# weight: 0
# acceleration: 0
# model year: 0
# origin: 0
# car name: 0

# %%
des=auto.describe(include='all')
des
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN        150          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  model year      origin    car name
# count     398.000000  398.000000  398.000000         398
# ...

# %%
auto['horsepower'].replace('?',des['horsepower'][2],inplace=True)
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_19804\434656396.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   auto['horsepower'].replace('?',des['horsepower'][2],inplace=True)

# %%
for i in auto.columns:
    print(f"{i}: {sum(auto[i]=='?')}")
# Out:
# mpg: 0
# cylinders: 0
# displacement: 0
# horsepower: 0
# weight: 0
# acceleration: 0
# model year: 0
# origin: 0
# car name: 0

# %%
auto.horsepower = auto.horsepower.astype('float')
auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
sns.distplot(auto.horsepower,color='green')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.displot(auto.horsepower,fill=False,color='red',hatch='--')
plt.show()

# %%
sns.kdeplot(auto.horsepower,fill=True,hatch='*',color='yellow')
plt.show()

# %%
sns.boxplot(x = auto.horsepower,y = auto.displacement,palette='cool')
plt.show()

# %%
sns.violinplot(x = auto.horsepower,y = auto.displacement,palette='cool')
plt.show()

# %%
sns.swarmplot(x = auto.horsepower,y = auto.displacement,palette='cool')
plt.show()

# %%
sns.barplot(x = auto.horsepower,y = auto.displacement,palette='hot')
plt.show()

# %%
plt.figure(figsize=(30,25))
sns.countplot(x = auto.horsepower,palette='deep')
plt.show()

# %%
sns.scatterplot(x = auto.horsepower , y = auto.displacement , hue = auto.cylinders,palette='deep')
plt.show()

# %%
sns.jointplot(data=auto)
plt.show()

# %%
sns.jointplot(data=auto,kind='kde')
plt.show()

# %%
sns.pairplot(auto)
plt.show()

# %%
sns.pairplot(auto,hue = 'cylinders')
plt.show()

# %% [markdown]
# ### Student Mark Set

# %%
mark = pd.read_csv(r"C:\Users\surya\OneDrive\Desktop\AIML_CTTC\NOTES\Student_Marks.csv")
mark
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
sns.distplot(mark.Marks,color='pink')
plt.show()

# %%
sns.displot(mark.Marks,fill=False,color='red',hatch='/')
plt.show()

# %%
sns.displot(mark.Marks,fill=True,color='red',hatch='*')
plt.show()

# %%
sns.kdeplot(mark.Marks,fill=True,hatch='*',color='yellow')
plt.show()

# %%
sns.boxplot(x = mark.number_courses,y = mark.time_study,palette='cool')
plt.show()

# %%
sns.violinplot(x = mark.number_courses,y = mark.time_study,palette='cool')
plt.show()

# %%
sns.swarmplot(x = mark.number_courses,y = mark.time_study,palette='cool')
plt.show()

# %%
sns.barplot(x = mark.number_courses,y = mark.time_study,palette='cool')
plt.show()

# %%
sns.countplot(x = mark.number_courses,palette='cool')
plt.show()

# %%
sns.scatterplot(x = mark.number_courses,y = mark.time_study,hue=mark.Marks,palette='cool')
plt.show()

# %%
sns.pairplot(mark)
plt.show()

# %%
sns.pairplot(mark,hue = 'Marks')
plt.show()
